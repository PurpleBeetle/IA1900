# %% [markdown]
# <a href="https://colab.research.google.com/github/PurpleBeetle/IA1900/blob/main/Tarea2/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


# Ejercicio 1: Análisis de Ventas
# Utilice el archivo ventas.csv para responder lo siguiente:
#1. Cargue los datos en un DataFrame
ventas = pd.read_csv('ventas.csv')
ventas
# Out:
#        Producto  Cantidad  Precio_Unitario
# 0        Webcam        15               74
# 1       Monitor        19              866
# 2     Impresora        12              848
# 3        Webcam         3              530
# 4       Teclado         5              353
# 5   Silla Gamer        19              138
# 6     Impresora         7              657
# 7     Impresora         9              481
# 8        Webcam         7               72
# 9         Mouse        18              148
# 10      Teclado         4              508
# 11       Webcam        14              602
# 12      Teclado        18              401
# 13      Teclado         9              684
# 14  Silla Gamer         2              428
# 15    Impresora        15              298
# 16      Monitor         7              388
# 17  Silla Gamer        12              782
# 18  Silla Gamer         8              499
# 19      Teclado        15              240
# 20  Auriculares         3               50
# ...

# %%
#2. Calcule la cantidad total de productos vendidos por categoría
ventas_por_categoria = ventas.groupby('Producto')['Cantidad'].sum()
ventas_por_categoria

# aqui sumamos la grupacion de productos por cantidad
# Out:
# Producto
# Auriculares     53
# Impresora       65
# Laptop          49
# Monitor        113
# Mouse           55
# Silla Gamer     77
# Teclado         73
# Webcam          56
# Name: Cantidad, dtype: int64

# %%
#3. Determine cuál es el producto con el mayor total de ventas.

producto_top = ventas_por_categoria.idxmax()
producto_top

# Aqui usamos idxmax para el indice del df de ventas
# Out:
# 'Monitor'

# %%
#4. Encuentre el precio promedio de los productos vendidos.
precio_promedio = ventas.groupby('Producto')['Precio_Unitario'].mean()
precio_promedio

# se una mean() para conseguir el promedio de ventas por las agrupaciones de producto
# Out:
# Producto
# Auriculares    437.500000
# Impresora      490.000000
# Laptop         771.333333
# Monitor        669.500000
# Mouse          354.000000
# Silla Gamer    480.500000
# Teclado        530.285714
# Webcam         340.000000
# Name: Precio_Unitario, dtype: float64

# %%
# Ejercicio 2: Análisis del Clima
# Utilice el archivo clima.csv para analizar los datos climáticos:
# 1.Cargue el dataset y conviértelo en un DataFrame.

clima = pd.read_csv('clima.csv')
clima
# Out:
#           Fecha            Ciudad  Temperatura
# 0    2023-01-01            Bogotá        25.84
# 1    2023-01-02          Santiago        14.75
# 2    2023-01-03            Madrid        15.91
# 3    2023-01-04            Madrid        12.10
# 4    2023-01-05  Ciudad de México        -3.98
# ..          ...               ...          ...
# 360  2023-12-27      Buenos Aires        -0.55
# 361  2023-12-28          Santiago        14.71
# 362  2023-12-29  Ciudad de México        -4.55
# 363  2023-12-30  Ciudad de México        13.75
# 364  2023-12-31  Ciudad de México        -2.75
#
# [365 rows x 3 columns]

# %%
# 2.Calcule la temperatura promedio de cada ciudad.
clima_promedio = clima.groupby('Ciudad')['Temperatura'].mean()
clima_promedio

# Usamos mean() para calcular el promedio de temperatura por la agrupacion de ciudades
# Out:
# Ciudad
# Bogotá              14.650794
# Buenos Aires        15.226571
# Ciudad de México    17.250833
# Madrid              13.870000
# Santiago            13.993718
# Name: Temperatura, dtype: float64

# %%
# 3.Determine el registro con la temperatura más alta y el más bajo en el dataset
registro_max = clima.loc[clima['Temperatura'].idxmax()]
registro_min = clima.loc[clima['Temperatura'].idxmin()]
registro_max


#conseguimos el indice maximo y mino del row por Temperatura
# Out:
# Fecha          2023-10-24
# Ciudad             Madrid
# Temperatura         34.62
# Name: 296, dtype: object

# %%
registro_min
# Out:
# Fecha          2023-04-25
# Ciudad             Madrid
# Temperatura          -4.8
# Name: 114, dtype: object

# %%
# 4. Identifique qué ciudad tuvo la temperatura más alta y cuál la más baja en todo el dataset.
ciudad_mas_caliente = registro_max['Ciudad']
ciudad_mas_fria = registro_min['Ciudad']
ciudad_mas_caliente

#Ya teniendo indices, solo se hacen la referencia con la ciudad.
# Out:
# 'Madrid'

# %%
ciudad_mas_fria
# Out:
# 'Madrid'

# %%
# 5.Encuentre cuántos registros tienen una temperatura mayor a 30°C.

temp_mayor_30 = clima[clima['Temperatura'] > 30].reset_index(drop=False)
temp_mayor_30

# filtramos todas las temperaturas mayor a 30, y hacemos reset el indice para reconocer la cantidad
# Out:
#     index       Fecha            Ciudad  Temperatura
# 0      10  2023-01-11            Madrid        31.30
# 1      18  2023-01-19          Santiago        32.19
# 2      24  2023-01-25  Ciudad de México        30.70
# 3      27  2023-01-28            Madrid        30.84
# 4      40  2023-02-10          Santiago        32.72
# 5      45  2023-02-15      Buenos Aires        33.87
# 6      46  2023-02-16            Bogotá        33.50
# 7      56  2023-02-26            Madrid        31.33
# 8      60  2023-03-02            Bogotá        34.43
# 9      84  2023-03-26  Ciudad de México        32.47
# 10     88  2023-03-30      Buenos Aires        31.99
# 11     89  2023-03-31            Madrid        30.09
# 12     97  2023-04-08  Ciudad de México        30.89
# 13     98  2023-04-09          Santiago        31.02
# 14    103  2023-04-14      Buenos Aires        30.88
# 15    104  2023-04-15  Ciudad de México        30.48
# 16    109  2023-04-20  Ciudad de México        30.94
# ...

# %%
# 6.Cuenta cuántos días en total hay registrados por cada ciudad.

dias_por_ciudad = clima['Ciudad'].value_counts()
dias_por_ciudad

# usamos value_counts para contar los valores de Ciudad
# Out:
# Ciudad
# Madrid              82
# Santiago            78
# Ciudad de México    72
# Buenos Aires        70
# Bogotá              63
# Name: count, dtype: int64

# %%
# Ejercicio 3: Estadísticas de Calificaciones
# Utilice el archivo calificaciones.csv para analizar el rendimiento de los estudiantes:

#1. Cargue el dataset y muestre las primeras filas.
calificaciones = pd.read_csv('calificaciones.csv')
calificaciones.head()

# head() nos ayuda imprimir los primeros 5 registros.
# Out:
#       Estudiante      Materia  Calificación
# 0   Estudiante_7         Arte            99
# 1  Estudiante_51  Matemáticas            55
# 2  Estudiante_72  Matemáticas            58
# 3  Estudiante_42  Matemáticas            82
# 4  Estudiante_64       Inglés            90

# %%
#2. Calcule el promedio de calificaciones por materia.
promedio_materia = calificaciones.groupby('Materia')['Calificación'].mean()
promedio_materia

#similar a otros ejercicios, tenemos el promedio con mean() de las calificaciones de la agrupacion de materias
# Out:
# Materia
# Arte           74.823529
# Ciencias       73.712766
# Historia       73.087379
# Inglés         72.740385
# Matemáticas    73.659794
# Name: Calificación, dtype: float64

# %%
#3. Identifique el estudiante con el promedio más alto.
promedio_lato = calificaciones.loc[calificaciones['Calificación'].idxmax()]
estudiantes_promedio_alto = promedio_lato['Estudiante']
estudiantes_promedio_alto

#se filtra el nombre de estudiante por el indice del filtro de calificaciones
# Out:
# 'Estudiante_7'

# %%
# 4. Agrupa las calificaciones por estudiante y calcule el promedio de cada uno.
estudiantes_promedio = calificaciones.groupby('Estudiante')['Calificación'].mean()
estudiantes_promedio

# el promedio de calificaciones por la agrupacion de estudiantes
# Out:
# Estudiante
# Estudiante_1      79.428571
# Estudiante_10     80.600000
# Estudiante_100    60.000000
# Estudiante_11     75.000000
# Estudiante_12     65.000000
#                     ...
# Estudiante_95     85.500000
# Estudiante_96     59.500000
# Estudiante_97     86.400000
# Estudiante_98     76.571429
# Estudiante_99     67.000000
# Name: Calificación, Length: 99, dtype: float64

# %%
# 5. Identifique cuántos estudiantes tienen un promedio superior a 85.
estudiantes_sobresalientes = estudiantes_promedio[estudiantes_promedio > 85].count()
estudiantes_sobresalientes

# se cuentan cuantos estudiantes con la condicion > 85 hay en en el df
# Out:
# np.int64(5)

# %%
# 6. Encuentre la materia con la mayor cantidad de calificaciones registradas.
materia_mas_calificaciones = calificaciones['Materia'].value_counts().idxmax()
materia_mas_calificaciones

#Se consigue el indice de la materia con el value_counts()
# Out:
# 'Inglés'

# %%
# 7. Muestre los 5 estudiantes con el promedio más bajo.
peores_estudiantes = estudiantes_promedio.sort_values().head()
peores_estudiantes

# se ordenan los valores y como esta descendiente por default, se usa head()
# Out:
# Estudiante
# Estudiante_79    51.0
# Estudiante_58    57.0
# Estudiante_91    58.0
# Estudiante_50    59.0
# Estudiante_80    59.0
# Name: Calificación, dtype: float64
