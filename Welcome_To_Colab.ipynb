# %% [markdown]
# <a href="https://colab.research.google.com/github/PurpleBeetle/IA1900/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

ventas = pd.read_csv('ventas.csv')
ventas
# Out:
#        Producto  Cantidad  Precio_Unitario
# 0        Webcam        15               74
# 1       Monitor        19              866
# 2     Impresora        12              848
# 3        Webcam         3              530
# 4       Teclado         5              353
# 5   Silla Gamer        19              138
# 6     Impresora         7              657
# 7     Impresora         9              481
# 8        Webcam         7               72
# 9         Mouse        18              148
# 10      Teclado         4              508
# 11       Webcam        14              602
# 12      Teclado        18              401
# 13      Teclado         9              684
# 14  Silla Gamer         2              428
# 15    Impresora        15              298
# 16      Monitor         7              388
# 17  Silla Gamer        12              782
# 18  Silla Gamer         8              499
# 19      Teclado        15              240
# 20  Auriculares         3               50
# ...
